# %% [markdown]
# # Testing Additional Biases

# %% [markdown]
# The purpose of this script is to test de-biasing based on Socioeconomic Status and Age. This Notebook is based on examples notebook provided by the original researchers of Man is to Programmer as Woman is to Homemaker? Debiasing Word Embeddings (https://arxiv.org/abs/1607.06520).
#
# The scripts used and the example iPython Notebook can be found in their github repository at https://github.com/tolga-b/debiaswe
#
# This is separate student project meant to build upon some of the results dicussed in the report and code located at
# https://github.com/nathanag/debiaswe

# %% [markdown]
# ## Part 1: Setup

# %% [markdown]
# ### Step 1: Import relevant libraries and modules

# %%
from __future__ import print_function, division
# %matplotlib inline
from matplotlib import pyplot as plt
import json
import random
import numpy as np

import debiaswe as dwe
import debiaswe.we as we
from debiaswe.we import WordEmbedding
from debiaswe.data import load_professions
from debiaswe.debias import debias

# %% [markdown]
# ### Step 2: Import Data

# %%
# load google news word2vec
E = WordEmbedding('./embeddings/w2v_gnews_small.txt')

# load professions
professions = load_professions()
profession_words = [p[0] for p in professions]
# Out:
# *** Reading data from ./embeddings/w2v_gnews_small.txt
# (26423, 300)
# 26423 words of dimension 300 : in, for, that, is, ..., Jay, Leroy, Brad, Jermaine
# Loaded professions
# Format:
# word,
# definitional female -1.0 -> definitional male 1.0
# stereotypical female -1.0 -> stereotypical male 1.0

# %% [markdown]
# ## Part 2: Age Based De-Biasing

# %%
# copy over word embedding to be used on Age de-biasing
E_age = E

# %% [markdown]
# ### Step 1: Define Age Direction

# %% [markdown]
# We define the bias direction using elderly - youthful as these word are more explicitly tied to human age than perhaps old - young.

# %%
# age direction
v_age = E_age.diff('elderly','youthful')

# %% [markdown]
# ### Step 2: Generating Analogies of "Elderly : x :: Youthful : y"

# %%
# analogies age
a_age = E_age.best_analogies_dist_thresh(v_age)

for (a,b,c) in a_age:
    print(a+"-"+b)
# Out:
# Computing neighbors
# Mean: 10.219732808538016
# Median: 7.0
# young-youthful
# elderly-middle_aged
# children-youngsters
# older-younger
# caring-nurturing
# mentally_ill-schizophrenic
# considerate-personable
# pensioner-schoolgirl
# seniors-sophomores
# kindness-humility
# poor-mediocre
# youths-youth
# sick-tired
# drunks-rowdy
# farmers-crop
# concerned-optimistic
# woman-teenager
# mothers-motherhood
# revitalization-revitalized
# appreciative-enthused
# hatchback-sporty
# adopts-embraces
# idyllic-carefree
# dog-bulldog
# apartment-dorm_room
# preparing-primed
# osteoporosis-acne
# adults-tweens
# victims-perpetrators
# bewildered-wide_eyed
# plight-travails
# collapsed-imploded
# foster-nurture
# uncooperative-combative
# receiving-garnering
# anxiety-excitement
# lends-exudes
# recognizes-embodies
# heartless-ruthless
# dementia-psychosis
# courageous-fearless
# antiques-vintage
# unwillingness-eagerness
# sentiment-optimism
# peasants-revolutionaries
# unconscionable-foolish
# affectionate-playful
# inadequate-lacking
# husband-younger_brother
# dozens-bevy
# callous-arrogant
# slept-partied
# adopting-embracing
# cats-neutered
# recognize-embody
# residents-voters
# noisy-boisterous
# vegetables-fruits
# innocent-innocence
# distraught-dejected
# unwilling-eager
# brake-throttle
# exquisite-sparkling
# falling-surging
# annoying-goofy
# outspoken-brash
# bothers-excites
# extraordinarily-remarkably
# cried-grinned
# aspirin-caffeine
# pensions-salaries
# mysterious-enigmatic
# citizens-citizenry
# smoke_inhalation-degree_burns
# maturities-maturity
# boyfriend-beau
# neighbor-cousin
# angry-disenchanted
# nutritious-wholesome
# outraged-taken_aback
# gullible-naive
# lady-beauty_queen
# mental_illness-delusions
# upsurge-resurgence
# carers-mums
# broad_daylight-brazen
# destitute-downtrodden
# traumatized-shell_shocked
# birds-butterflies
# sexual_abuse-sexual_misconduct
# pets-furry
# aunt-twin_sister
# heart_wrenching-bittersweet
# safeties-playmakers
# married_couples-heterosexual
# ambience-vibe
# posturing-bravado
# hairdresser-stylist
# triggered-fueled
# encourage-inspire
# morality-idealism
# lonely-melancholy
# extremely-undeniably
# evicted-expelled
# anathema-antithesis
# grandma-kid
# herded-paraded
# distressing-startling
# died-succumbed
# disenfranchised-disaffected
# unchecked-unbridled
# unaware-unfazed
# meal-delicious
# despicable-childish
# relaxing-relaxed
# nice-classy
# joy-exuberance
# farmland-pastures
# churches-evangelical
# folk-rock_n_roll
# eccentric-flamboyant
# cat-monkey
# oppressed-repressed
# evict-oust
# windy-breezy
# fancy-flashy
# farce-silliness
# relatives-friends
# quickness-athleticism
# daycare-kindergarten
# oversupply-glut
# freaking-psyched
# poorer-richer
# urgent-urgency
# suicidal-self_destructive
# jewelery-bling
# lots-plenty
# abuses-excesses
# coldest-darkest
# overflowing-brimming
# contaminated-tainted
# intimacy-spontaneity
# frightened-timid
# pregnant-pregnancy
# cafe-hangout
# psychotic-manic
# self_employed-freelance
# recharging-recharged
# apprehensive-gung_ho
# chronically-perpetually
# oversold-bullish
# hazardous-combustible
# advocacy-activism
# convicted-exonerated
# fatter-slimmer
# outrage-angst
# secluded-serene
# middle_aged-young
# deprived-bereft
# bravery-tenacity
# groceries-essentials
# difficulty-daunting_task
# actress-starlet
# life_expectancy-lifespan
# dressed-sported
# holds-retains
# vicious-fearsome
# underserved-untapped
# glad-confident
# angered-raised_eyebrows
# holidays-festive
# gentle-mellow
# bystanders-onlookers
# quilt-scrapbook
# practical-pragmatic
# confusing-muddled
# adequate-ample
# apartment_complexes-condominiums
# sobbing-smiling
# critics-detractors
# giggling-giddy
# accidents-mishaps
# ok-alright
# complained-bemoaned
# income-revenue
# employees-executives
# proposals-ideas
# metropolis-cosmopolitan
# cold_snap-dry_spell
# inland-westward
# pensioners-savers
# unresponsive-lifeless
# commotion-hoopla
# uncovered-unearth
# cinema-cinematic
# skills-talent
# eateries-nightlife
# received-garnered
# servicemen-comrades
# non_existent-devoid
# illustrates-epitomizes
# charities-philanthropic
# seeping-oozing
# society-culture
# disabled-deaf
# respite-solace
# double_whammy-double_edged_sword
# caregivers-pediatricians
# milk-juice
# hospitals-universities
# teenagers-somethings
# revived-reinvigorated
# cheeses-flavors
# adult-adolescent
# pornographic-racy
# paramedics-resuscitate
# worsens-falters
# required-requisite
# airman-cadet
# sheltering-hiding
# dorms-upperclassmen
# affect-alter
# heartening-refreshing
# prompts-inspires
# collapse-downfall
# shivering-sweaty
# fearful-jittery
# together-cohesive
# patients-clinical
# hardest-toughest
# illiterate-literate
# fathers-fatherhood
# vulnerable-prone
# clubbed-stroked
# recipients-honorees
# lovely-glorious
# severity-seriousness
# teachers-principals
# cooling-cooled
# adversely_affected-dampened
# compassion-sincerity
# explosive_device-explosive
# hug-smiles
# fixes-tweaks
# enraged-seething
# delusion-hubris
# girl-blonde
# indifference-arrogance
# schoolchildren-fifth_graders
# sobbed-smiled
# toddler-teen
# lung_disease-liver_disease
# sympathy-admiration
# mental_health-mental
# handicapped-handicap
# dogs-breeds
# apartments-villas
# air_conditioned-spacious
# uptight-cocky
# colonization-conquest
# depress-dampen
# leaflets-posters
# declared-proclaimed
# systems-capabilities
# leaflet-flyer
# simulate-replicate
# placard-banner
# brighten-sparkle
# hardship-hardships
# firefighters-firefighting
# unusually-surprisingly
# planting-cultivating
# thought-seemed
# exacerbate-heighten
# dialysis-transplant
# administers-manages
# risk_aversion-pessimism
# food-beverages
# expressed_concern-downplayed
# transgender-sexuality
# veterans-veteran
# suggested-hinted
# ironing-ironed
# hypothermia-dehydration
# weak-lackluster
# rice-mango
# polishing-polished
# crying-giggling
# babies-twins
# irate-incredulous
# crap-haters
# refers-characterizes
# provider-marketer
# dispute-controversy
# somebody-whatever
# wandered-strode
# business-entrepreneurial
# stuffy-staid
# teams-team
# carer-mum
# enjoy-revel
# unethical-unprofessional
# principle-philosophy
# gas-energy
# concern-nervousness
# enjoying-reveling
# angrily-defiantly
# appalling-ghastly
# harmonica-keyboardist
# unaffordable-prohibitive
# haven-hotbed
# pushed-propelled
# severe-serious
# mildly-decidedly
# hospitalized-underwent_surgery
# shelter-refuge
# incensed-bemused
# vine-buds
# exceeds-surpasses
# Latonya-Tanisha
# lineout-backline
# simmering-bubbling
# criticized-lauded
# bearded-lanky
# descendants-lineage
# childcare-parenting
# smokers-nicotine
# passer-playmaker
# denies-insists
# dogma-ethos
# worsened-soured
# air_conditioner-radiator
# ailing-faltering
# residing-resides
# sufferers-cure
# thankful-excited
# possibly-perhaps
# disturbed-amused
# uninsured-enrollees
# obese-fat
# heroin-ecstasy
# cleaning-clean
# inheritance-heirs
# inflated-deflated
# complains-laments
# car-coupe
# complaining-lamenting
# deliberate-purposeful
# broken-fractured
# meals-snacks
# elementary-eighth_grade
# grocery-retailing
# homeless-homelessness
# regressive-reactionary
# mitigate-neutralize
# stimulating-invigorating
# worried-unconcerned
# innovation-creativity
# education-curricula
# crack_cocaine-cocaine
# wheelchairs-bikes
# teenage_girl-teenage
# wages-salary
# cold-frosty
# affected-unaffected
# objections-misgivings
# provides-boasts
# scarf-shirt
# determining-determined
# cranky-jaded
# workers-workforce
# her-his
# gala-star_studded
# cloning-clone
# separate-distinct
# stimulate-energize
# carelessness-inexperience
# mountainous-rugged
# genius-brilliance
# grateful-ecstatic
# because-though
# verbal_abuse-taunts
# alarmed-intrigued
# arts-artistic
# officer-chief
# unhelpful-dismissive
# rescued-plucked
# unusual-surprising
# waiting-hoping
# luggage-baggage
# mortgage-loan
# delays-hiccups
# slippers-sneakers
# tsunami-tidal_wave
# husbands-girlfriends
# pajamas-shirts
# neighbors-cousins
# hip_replacement-surgery
# driveways-ditches
# disputes-controversies
# crowded-bustling
# posh-glamorous
# complain-brag
# hugged-jubilant
# deportation-expulsion
# peacefully-peaceful
# intimidate-overpower
# ethnic_minorities-ethnicities
# grandfather-boyhood
# mother-father
# improvements-additions
# invalid-annulled
# incomes-disposable_income
# commonly_referred-popularly_known
# dining_room-airy
# residence_halls-incoming_freshmen
# appetite-enthusiasm
# deliberately-consciously
# professions-careers
# landlord-owner
# winter-springtime
# exacerbating-fueling
# beige-navy_blue
# efficacy-potency
# prostitution-sexual
# mammogram-biopsy
# attacked-overran
# needy-underprivileged
# heartwarming-captivating
# bigoted-crass
# preserving-retaining
# observance-celebration
# possessions-possession
# sleeping-lounging
# radiotherapy-tumor
# terrifying-exhilarating
# soldiers-battalions
# seventies-heyday
# assaulted-manhandled
# conservatives-conservatism
# pastries-delectable
# grandparents-brothers
# van-wagon
# slashed-trimmed
# won-victorious
# someone-something
# tutor-mentor
# manmade-natural
# hurt-dented
# estimated-projected
# mentally-mental_toughness
# motorist-careless_driving
# hysterical-comical
# experiments-experimentation
# unsuspecting-hapless
# sex_couples-sex_marriage
# quarrel-fracas
# dividend-dividends
# family-clan
# grocery_stores-retail_outlets
# apartment_complex-strip_mall
# chap-jolly
# belongings-mementos
# schools-academies
# parishioners-priesthood
# objected-bristled
# swimming_pool-fountain
# kids-fun
# soup-ketchup
# taught-instilled
# warns-concedes
# rejuvenation-rejuvenated
# knowledgeable-seasoned
# boy-youngster
# sitting-staring
# unnecessarily-needless
# prostitutes-seedy
# forecasting-projecting
# bashed-thumped
# feud-rivalry
# defines-embodied
# patent-trademark
# cooking-culinary
# staples-mainstays
# mystery-intrigue
# disappeared-faded
# childhood-formative
# drain-flushed
# loneliness-insecurities
# greenery-splendor
# scarce-abundant
# aroma-sweetness
# impacted-influenced
# angering-alienating
# duped-seduced
# alleviate-dispel
# dire-rosy
# students-grads
# endangers-sustains
# disadvantages-pitfalls

# %% [markdown]
# ### Step 3: Analyzing age bias in word vectors associated with professions

# %%
# profession analysis age
sp = sorted([(E_age.v(w).dot(v_age), w) for w in profession_words])

sp[0:20], sp[-20:]
# Out:
# ([(-0.20439817, 'firebrand'),
#   (-0.17037404, 'skipper'),
#   (-0.16300799, 'protege'),
#   (-0.15634924, 'soft_spoken'),
#   (-0.15512511, 'captain'),
#   (-0.14762147, 'character'),
#   (-0.14514217, 'understudy'),
#   (-0.13874087, 'maestro'),
#   (-0.13791606, 'vocalist'),
#   (-0.12872238, 'midfielder'),
#   (-0.12415519, 'alter_ego'),
#   (-0.117710695, 'coach'),
#   (-0.11735272, 'drummer'),
#   (-0.11567702, 'performer'),
#   (-0.11487635, 'boss'),
#   (-0.11357656, 'dancer'),
#   (-0.108110696, 'crooner'),
#   (-0.10684258, 'stylist'),
#   (-0.09997366, 'commander'),
#   (-0.099105045, 'protagonist')],
#  [(0.14806971, 'parishioner'),
#   (0.15078013, 'pharmacist'),
#   (0.15097722, 'firefighter'),
#   (0.15188062, 'constable'),
#   (0.1610317, 'advocate'),
#   (0.16266564, 'serviceman'),
#   (0.16472465, 'trucker'),
#   (0.16831487, 'nanny'),
#   (0.17195654, 'laborer'),
#   (0.17439684, 'handyman'),
#   (0.17853151, 'employee'),
#   (0.1785875, 'policeman'),
#   (0.18029651, 'shopkeeper'),
#   (0.18213417, 'taxi_driver'),
#   (0.18763213, 'registered_nurse'),
#   (0.18925573, 'sheriff_deputy'),
#   (0.18954019, 'housekeeper'),
#   (0.19406497, 'landlord'),
#   (0.1967125, 'nurse'),
#   (0.2514648, 'worker')])

# %% [markdown]
# ### Step 4: Debias based on age

# %%
# Lets load some age related word lists to help us with debiasing
with open('./data/age_definitional_pairs.json', "r") as f:
    age_defs = json.load(f)
print("definitional", age_defs)

with open('./data/age_equalize_pairs.json', "r") as f:
    age_equalize_pairs = json.load(f)
print("equalize", age_equalize_pairs)
with open('./data/age_specific_seed.json', "r") as f:
    age_specific_words = json.load(f)
print("gender specific", len(age_specific_words), age_specific_words[:10])
# Out:
# definitional [['aged', 'young'], ['parent', 'child'], ['elder', 'youth'], ['past', 'future'], ['old', 'new'], ['death', 'birth'], ['mature', 'immature'], ['expert', 'novice'], ['grandparent', 'grandchild'], ['elderly', 'youthful']]
# equalize [['parent', 'child'], ['teacher', 'student'], ['grandparent', 'grandkid'], ['grandparents', 'grandkids'], ['grandfather', 'grandson'], ['grandmother', 'granddaughter'], ['retirement_home', 'nursery'], ['retiree', 'entry_level_worker'], ['adult', 'kid'], ['senior', 'freshman'], ['father', 'son'], ['mother', 'daughter']]
# gender specific 24 ['parent', 'child', 'teacher', 'student', 'grandparent', 'grandkid', 'grandparents', 'grandkids', 'grandfather', 'grandson']

# %%
debias(E_age, age_specific_words, age_defs, age_equalize_pairs)
# Out:
# 26423 words of dimension 300 : in, for, that, is, ..., Jay, Leroy, Brad, Jermaine
# {('GRANDPARENT', 'GRANDKID'), ('retirement_home', 'nursery'), ('Adult', 'Kid'), ('grandparents', 'grandkids'), ('retiree', 'entry_level_worker'), ('Father', 'Son'), ('Teacher', 'Student'), ('Grandfather', 'Grandson'), ('Parent', 'Child'), ('Retirement_Home', 'Nursery'), ('adult', 'kid'), ('Grandparent', 'Grandkid'), ('mother', 'daughter'), ('parent', 'child'), ('TEACHER', 'STUDENT'), ('teacher', 'student'), ('GRANDPARENTS', 'GRANDKIDS'), ('Retiree', 'Entry_Level_Worker'), ('FATHER', 'SON'), ('Mother', 'Daughter'), ('ADULT', 'KID'), ('grandfather', 'grandson'), ('RETIREMENT_HOME', 'NURSERY'), ('MOTHER', 'DAUGHTER'), ('GRANDMOTHER', 'GRANDDAUGHTER'), ('grandmother', 'granddaughter'), ('GRANDFATHER', 'GRANDSON'), ('PARENT', 'CHILD'), ('Grandmother', 'Granddaughter'), ('SENIOR', 'FRESHMAN'), ('father', 'son'), ('Grandparents', 'Grandkids'), ('senior', 'freshman'), ('grandparent', 'grandkid'), ('RETIREE', 'ENTRY_LEVEL_WORKER'), ('Senior', 'Freshman')}
# 26423 words of dimension 300 : in, for, that, is, ..., Jay, Leroy, Brad, Jermaine

# %% [markdown]
# ### Step 5: Analyzing age bias in professions post debiasing

# %%
# profession analysis age
sp_debiased = sorted([(E_age.v(w).dot(v_age), w) for w in profession_words])

sp_debiased[0:20], sp_debiased[-20:]
# Out:
# ([(-0.3091138, 'student'),
#   (-0.20400825, 'soft_spoken'),
#   (-0.1516062, 'firebrand'),
#   (-0.14507702, 'skipper'),
#   (-0.14192595, 'maestro'),
#   (-0.13913538, 'vocalist'),
#   (-0.13761961, 'crooner'),
#   (-0.13602431, 'guitarist'),
#   (-0.13209036, 'drummer'),
#   (-0.13118091, 'captain'),
#   (-0.12988138, 'protege'),
#   (-0.12250668, 'stylist'),
#   (-0.12145236, 'singer'),
#   (-0.11868984, 'understudy'),
#   (-0.112814255, 'dancer'),
#   (-0.11172544, 'confesses'),
#   (-0.10882473, 'midfielder'),
#   (-0.107521325, 'alter_ego'),
#   (-0.10380973, 'investment_banker'),
#   (-0.101790324, 'doctoral_student')],
#  [(0.03428898, 'rabbi'),
#   (0.03568951, 'handyman'),
#   (0.037688643, 'janitor'),
#   (0.04216937, 'tutor'),
#   (0.042986553, 'housekeeper'),
#   (0.04361617, 'pharmacist'),
#   (0.04777269, 'warden'),
#   (0.047919422, 'lifeguard'),
#   (0.047979757, 'sheriff_deputy'),
#   (0.048308235, 'advocate'),
#   (0.0492267, 'firefighter'),
#   (0.050726738, 'fireman'),
#   (0.05111678, 'landlord'),
#   (0.053630207, 'receptionist'),
#   (0.05733846, 'nanny'),
#   (0.05934367, 'citizen'),
#   (0.060545713, 'nurse'),
#   (0.061953187, 'employee'),
#   (0.077603, 'worker'),
#   (0.29833576, 'teacher')])

# %% [markdown]
# ### Step 6: Analyzing debiased analogies

# %%
# analogies age
a_age_debiased = E_age.best_analogies_dist_thresh(v_age)

for (a,b,c) in a_age_debiased:
    print(a+"-"+b)
# Out:
# Computing neighbors
# Mean: 10.160844718616357
# Median: 7.0
# grandparents-grandkids
# son-father
# mother-daughter
# grandson-grandfather
# teacher-student
# grandmother-granddaughter
# senior-sophomore
# kids-kid
# children-parent
# junior-freshman
# child-toddler
# adult-kids
# elderly-young
# younger-youthful
# young-old
# grandparent-grandpa
# veterans-veteran
# dog-bulldog
# mentally_ill-schizophrenic
# very-remarkably
# families-family
# oppressed-repressed
# seniors-sophomores
# adults-olds
# immigrants-immigrated
# noisy-boisterous
# babies-twins
# youngsters-youngster
# vulnerable-prone
# lends-exudes
# navigate-navigated
# considerate-personable
# drunks-rowdy
# compassion-humility
# solicitors-barrister
# brave-fearless
# pets-pup
# profess-professed
# dementia-liver_disease
# announcements-pronouncements
# laborers-laborer
# dedication-tenacity
# voiced_concern-lamented
# sick-tired
# neighbor-cousin
# committing_suicide-committed_suicide
# exceptional-impeccable
# uncertainty-pessimism
# disenfranchised-alienated
# heartless-arrogant
# parents-stepfather
# residents-resident
# woman-boy
# lady-beauty_queen
# confused-bemused
# unintended-unintentional
# elders-elder
# widowed-remarried
# owners-owner
# farmers-farmer
# wonderful-splendid
# excited-enthused
# mothers-daughters
# wary-circumspect
# turban-beard
# posturing-bravado
# reservists-reservist
# drug_addicts-drug_addict
# teenagers-teenaged
# homosexuals-homosexuality
# hardship-anguish
# enjoy-savor
# plight-travails
# joy-exuberance
# illustrates-belies
# grandchildren-eldest
# citizens-citizen
# handicapped-handicap
# them-him
# recharging-recharged
# poor-dismal
# lonely-melancholy
# mental_health-psychiatrist
# hello-smiled
# bilingual-fluent
# healthier-fresher
# benefit-benefited
# cold-frosty
# dark_colored-brown_hair
# fostering-cultivating
# alleviate-stem
# create-recreate
# servicemen-comrades
# relaxing-relaxed
# pensioner-schoolgirl
# mitigate-neutralize
# recognizes-embodies
# pondered-chuckled
# unconscionable-outrageous
# animal_shelter-zoo
# warns-concedes
# shorting-contrarian
# would-had
# outraged-incredulous
# exemplifies-personified
# living-lived
# practical-pragmatic
# smoke_inhalation-degree_burns
# osteoporosis-acne
# civil_servants-civil_servant
# recycling-recycled
# hone-honed
# confusing-maddening
# hazardous-combustible
# extraordinary-remarkable
# creates-evokes
# residing-resides
# blind-blinded
# addicts-addict
# mysterious-enigmatic
# brake-throttle
# preparing-primed
# paramedics-pronounced_dead
# provides-boasts
# nice-classy
# devised-perfected
# students-classmates
# appreciation-admiration
# childcare-maternity_leave
# stimulating-invigorating
# strangers-acquaintances
# ok-alright
# spend-spent
# develop-cultivate
# nicer-sweeter
# designed-engineered
# broad_daylight-brazen
# terrifying-fearsome
# cold_snap-dry_spell
# relatives-uncle
# ie-whereas
# extremely-amazingly
# brighten-cheery
# boxing-knockouts
# homes-bungalow
# unaware-unfazed
# next-later
# skills-prowess
# rhetoric-bluster
# fast_paced-frenetic
# unhelpful-dismissive
# broken-cracked
# older-younger
# planting-planted
# surfers-surfer
# apprentices-apprentice
# taxi_drivers-taxi_driver
# musicians-keyboardist
# long_awaited-belated
# anathema-antithesis
# proficiency-mastery
# revitalized-rejuvenated
# destitute-hopeless
# click-clicked
# smoking-puffing
# polite-jovial
# pupils-headmaster
# husband-younger_brother
# meal-delicious
# irresponsible-shameless
# commonly_referred-popularly_known
# tall-lanky
# newcomers-newcomer
# threes-footer
# toiletries-shampoo
# elementary-sixth_grader
# entrepreneurs-entrepreneur
# exceeds-surpasses
# foster-fostered
# deserving-deserved
# ski-skied
# disabilities-cerebral_palsy
# adopts-embraces
# soothing-mellow
# struggling-struggled
# journeys-odyssey
# communities-region
# wondered-marveled
# my-his
# herded-paraded
# middle_aged-bearded
# anxiety-elation
# cooling-cooled
# dropouts-dropout
# electricians-electrician
# daycare-kindergarten
# bosses-boss
# distressing-shocking
# beset-dogged
# defined-characterized
# grateful-ecstatic
# go-gone
# cinema-filmmaker
# meals-desserts
# pet-veterinarian
# downsized-shrunk
# affordable_housing-condominiums
# bowling-wicketkeeper
# abused-molested
# fancy-flashy
# retarded-immature
# due-attributed
# exciting-eventful
# wind_turbine-megawatt
# novice-seasoned
# teens-adolescent
# terrorized-tormented
# amenity-frontage
# eccentric-flamboyant
# uncertain-optimistic
# contentious-testy
# dumb-goofy
# contaminated-tainted
# caring-loving
# mental_illnesses-alcoholism
# nieces-nephew
# housing-real_estate
# needed-lacked
# innocent-innocence
# uncooperative-combative
# vitality-vigor
# peasants-revolutionaries
# agreeable-amiable
# courageous-gutsy
# baskets-putback
# monsters-demon
# businesses-firms
# birds-feathers
# expressed_concern-downplayed
# creating-recreating
# smokers-smokes
# organize-organizer
# bottled_water-bottled
# sincerely-sincerity
# enjoying-reveling
# dense-thick
# skill-finesse
# widows-widow
# adversely_affected-dampened
# jeopardized-ruined
# somebody-he
# seeping-oozing
# nursery-flower
# mental_illness-delusions
# homelessness-drug_addiction
# exacerbating-compounded
# caregivers-pediatricians
# undesirable-unsavory
# confusion-angst
# society-culture
# vistas-splendor
# accumulate-accumulated
# disabled-deaf
# concerned-unconcerned
# cleaning-scrubbing
# refugees-returnees
# sir-replied
# small-minuscule
# dislocated-bruised
# securitization-origination
# someone-guy
# yelled-grinned
# smart-shrewd
# clans-clan
# ambitious-audacious
# apprehensive-gung_ho
# curtains-shades
# wander-strolled
# transgender-sexuality
# estranged_wife-stepdaughter
# themselves-himself
# proponents-detractors
# qualifications-credentials
# ethnic_minorities-ethnic
# racers-racer
# mentoring-mentor
# chick-blonde
# governments-administrations
# inquisitive-wide_eyed
# pedestrians-thoroughfare
# compassionate-sincere
# maturities-maturity
# revitalization-rebirth
# turmoil-tumult
# married_couples-marital
# women-male_counterparts
# dubbed-nicknamed
# shopkeepers-shopkeeper
# breeders-bred
# mares-gelding
# prestige-mystique
# skilled-skillful
# objected-scoffed
# retrieve-retrieved
# socializing-partying
# intending-attempted
# thousands-legions
# this-last
# crowded-bustling
# renewable_energy-renewable
# sorting-sifting
# theater-troupe
# find-unearth
# parolees-paroled
# actually-somehow
# sheltering-hiding
# hug-smiling
# proximity-closeness
# demeaning-unprofessional
# delays-hiccups
# allay-quash
# rescuing-salvaging
# indie-punk
# warned-insisted
# happening-transpired
# retirees-boomers
# kidding-chuckling
# rockers-frontman
# fathers-sons
# gifted-precocious
# particularly-nonetheless
# recognize-embody
# vote-votes
# schoolchildren-fifth_graders
# imaginative-playful
# recognizing-acknowledging
# zoom-zoomed
# illnesses-ailment
# fishermen-fisherman
# bowlers-seamer
# folks-dudes
# boost-bolstered
# abuses-excesses
# politicians-politician
# spurring-fueled
# cares-hates
# dreary-dour
# monks-monk
# retirement-retire
# potentially-conceivably
# evict-oust
# carers-carer
# undertaking-undertook
# urgent-urgency
# gentle-easygoing
# impacted-influenced
# watered-toned
# mean-equate
# donut-cheesecake
# dads-dad
# misleading-exaggerated
# cloning-clone
# repairs-repaired
# buffs-buff
# vicious-ferocious
# rely-relied
# quilts-paintings
# massively-spectacularly
# migrating-migrated
# chronic_diseases-ailments
# genius-brilliance
# essential-indispensable
# possibly-probably
# thorny-prickly
# rewarding-humbling
# dinner-dined
# owls-frogs
# soggy-soaked
# conundrum-enigma
# rivals-nemesis
# disagree-concur
# nurture-nurtured
# useless-fruitless
# advocate-campaigner
# critically_ill-ventilator
# termination-dismissal
# affluent-cosmopolitan
# apartments-storey
# commend-complimented
# defensively-composure
# dialysis-liver_transplant
# evicted-expelled
# frightened-shell_shocked
# aspire-aspired
# dole-doled
# strapped-strapping
# ready-raring
# feelings-bitterness
# hair_salon-stylist
# moving-inching
# accrual-accrued
# timid-cocky
# basic-rudimentary
# blaming-attributing
# democrats-democrat
# mulls-dismisses
# shelter-sanctuary
# ensure-assured
# redevelopment-demolish
# football-coach
# possess-possessed
# pushed-muscled
# appalled-taken_aback
# oncology-dermatology
# matchup-rivalry
# continual-relentless
# harmonica-guitarist
# animal_cruelty-misdemeanor
# idiots-stupidity
# innovative-innovator
# furry-hairy
# devious-wily
# rules-rule
# southeast-miles_northwest
# stingy-stout
# truckers-trucker
# officers-sergeant
# gay_couples-heterosexual
# pleased-impressed
# asthma-symptoms
# hurt-dented
# rub-rubbed
# walkways-boulevard
# intensive_care-underwent_surgery
# displaced-uprooted
# muscles-muscular
# greed-arrogance
# collapsing-imploded
# levee-dam
# cricket-paceman
# cats-tigers
# facing-faced
# fantastically-brilliantly
# educational-academic
# tenants-tenant
# physicists-physicist
# defines-characterizes
# businessmen-businessman
# completions-touchdown_pass
# wealthy-multimillionaire
# wind_turbines-windmills
# licensees-licensee
# so-though
# gimmicks-theatrics
# survivors-survivor
# also-meanwhile
# uplifting-joyous
# minorities-whites
# creatures-dinosaurs
# regeneration-regenerate
# intimidate-overpower
# nutritious-wholesome
# lots-plenty
# guardsmen-battalion
# teenage_girl-girl
# breakfast-oatmeal
# disadvantages-shortcomings
# secures-retains
# indecision-impatience
# deportation-extradited
# orphans-orphanage
# countrymen-countryman
# new-revamped
# churches-pastor
# swim-breaststroke
# dogs-poodle
# taking-took
# necessities-staples
# animals-monkeys
# piano-virtuoso
# literature-writings
# claimants-claims
# rounders-rounder
# parcels-acre_parcel
# jeopardize-tarnish
# alleviated-dissipated
# rugby-flanker
# alleviating-overcoming
# royal-regal
# blurring-blur
# peers-contemporaries
# multiple_sclerosis-psoriasis
# pensioners-pensioner
# offended-amused
# arthritis-aches
# runners-runner
# affirms-asserts
# thankful-elated
# differ-differed
# wide_range-gamut

# %% [markdown]
# ## Part 3: Socioeconmic Based De-Biasing

# %%
# copy over word embedding to be used on Socioeconomic de-biasing
E_se = E

# %% [markdown]
# ### Step 1: Define Socioeconomic Direction

# %% [markdown]
# We define the bias direction wealthy  - impoverished as these word are more explicitly tied to socioeconomic status/class than perhaps rich - poor.

# %%
# socioeconomic direction
v_se = E_se.diff('wealthy','impoverished')

# %% [markdown]
# ### Step 2: Generating Analogies of "Wealthy : x :: Impoverished : y"

# %%
# analogies socioecomic status
a_se = E_se.best_analogies_dist_thresh(v_se)

for (a,b,c) in a_se:
    print(a+"-"+b)
# Out:
# wealthiest-poorest
# wealthier-poorer
# poorer-impoverished
# wealthy-richest
# yachts-fishing_boats
# luxuries-basic_necessities
# educated-illiterate
# yacht-vessel
# capitalists-peasants
# secluded-desolate
# cottages-shacks
# corporations-governments
# terrorists-guerrillas
# communists-communist
# greedy-corrupt
# revolt-uprising
# earners-earner
# modest-meager
# affluent-populous
# socialite-actress
# civil_liberties-human_rights
# despicable-deplorable
# gullible-uneducated
# insiders-observers
# cynicism-hopelessness
# mansions-palaces
# cosmopolitan-metropolis
# disadvantaged-poverty_stricken
# inequality-poverty
# hectic-chaotic
# banker-lender
# terrorism-militancy
# millionaire-mogul
# obesity-malnutrition
# steak-fried_chicken
# skinny-emaciated
# compromise-accord
# opulent-lush
# distinguished-exemplary
# lousy-abysmal
# liberal-leftist
# speculators-traders
# oversupply-shortages
# maids-migrant_workers
# renovated-dilapidated
# steaks-beef
# stuffy-drab
# residences-neighborhoods
# sleazy-seedy
# mountain-mountainous
# ridge-plains
# lax-inadequate
# tax-levies
# venture_capitalist-startup
# polling-polling_stations
# businesses-communities
# socializing-socialization
# liberalism-democracy
# elites-dictatorships
# wallet-backpack
# draconian-repressive
# blond-brown_eyes
# bungalow-shack
# rosy-bleak
# clobbered-battered
# dehydrated-malnourished
# cadre-cadres
# bungalows-huts
# accountants-auditors
# gangsters-gangs
# appease-pacify
# misdemeanors-child_endangerment
# intrusions-incursions
# denizens-inhabitants
# dumb-retarded
# self_employed-unemployed
# strategists-analysts
# reasonable-adequate
# uber-insanely
# caved-crumbled
# friends-classmates
# prospered-flourished
# carbohydrates-nutrients
# sheltered-shelter
# drunken-unruly
# buys-receives
# calorie-nutritional
# disdain-defiance
# boutiques-stores
# turbulence-instability
# clueless-hopeless
# defer-suspend
# fascism-totalitarian
# gorgeous-mesmerizing
# treaty-disarmament
# jet-jetliner
# pharmaceutical-medicines
# crashing-tumbling
# thoughtful-thought_provoking
# young-youth
# employers-workers
# stupid-pathetic
# mining-mines
# caters-operates
# magnificent-awe_inspiring
# spacious-cramped
# sexually_active-adolescents
# royals-monarch
# buffeted-wracked
# famous-revered
# gung_ho-apprehensive
# marinas-waterways
# buddies-comrades
# subsidizing-subsidized
# smartest-funniest
# spectacular-electrifying
# pessimism-despair
# cliff-abyss
# tend-oftentimes
# refugee-refugee_camps
# terrorist-militant
# nice-awesome
# thirsty-parched
# screwing-messed
# conversations-dialogue
# credit_crunch-turmoil
# liberals-hardliners
# chiropractor-physical_therapy
# townspeople-villagers
# wife-daughter
# conclusive-inconclusive
# property-land
# man-boy
# broadening-bolstering
# flamboyant-mercurial
# pretense-semblance
# individuals-people
# winds-torrential_rains
# jihadists-insurgency
# protecting-safeguarding
# undeveloped-underdeveloped
# vile-filthy
# accessible-inaccessible
# fickle-unpredictable
# fireplaces-stoves
# continental-continent
# town-villages
# inclined-compelled
# small-tiny
# simplify-improve
# titans-behemoth
# downsize-reorganize
# Sarah-Keisha
# beachfront-coastal
# colonel-army
# villa-palace
# morph-transform
# expensive-prohibitive
# criminality-lawlessness
# distraught-devastated
# charming-captivating
# muse-inspiration
# indulged-resorted
# rational-illogical
# sensible-appropriate
# managed-struggled
# ties-diplomatic_ties
# condos-homes
# vaccinated-immunizations
# trashing-destroying
# despondent-demoralized
# married-baptized
# villas-resorts
# clients-customers
# sunny-sweltering
# arrogance-indifference
# males-youths
# urging-vowing
# flier-pamphlets
# voting-balloting
# beach-island
# hitters-mound
# preserve-restore
# real_estate-homebuilding
# greed-ignorance
# private-public
# global_warming-deforestation
# consumption-output
# chocolates-candy
# prostate_cancer-disease
# professor-associate_professor
# condom-condoms
# labor_unions-labor
# evidently-admittedly
# transgressions-violations
# deduction-deducted
# widows-orphans
# short_sighted-inefficient
# influenza-outbreak
# ruthless-brutal
# kidnappers-militants
# overspending-mismanagement
# starve-starvation
# colds-diarrhea
# ag-agriculture
# amused-pained
# chairman-chairperson
# video_conferencing-telemedicine
# expire-expired
# discriminating-discrimination
# wealth-riches
# corporates-telecom_operators
# hot_tub-shower
# funny-heartwarming
# distressed-troubled
# pleasure-joy
# advising-instructing
# tan-brown
# fighter_pilot-airman
# fossil_fuel-electricity
# plaintiff-appellant
# maverick-firebrand
# crowding-overcrowded
# beggars-destitute
# ranching-farming
# politicians-parliamentarians
# recessions-crises
# protected-unprotected
# princes-rulers
# heaven-salvation
# master_bedroom-kitchen
# renewables-hydropower
# hubris-bravado
# extremists-tribal_regions
# cripple-crippled
# clever-clumsy
# arraigned-probation_violation
# madness-chaos
# desserts-dishes
# backwards-backward
# brochure-booklets
# seductive-hypnotic
# disgraced-embattled
# astute-incisive
# bacon-fried
# footballer-youngster
# gaggle-throngs
# bankers-banks
# colleague-comrade
# mayonnaise-flour
# waterfront-estuary
# bash-extravaganza
# mesothelioma-lung_disease
# ought-shall
# deprive-deprived
# champagne-celebratory
# cars-trucks
# assuage-quell
# commando-paramilitary
# mortgage-mortgage_lender
# exempt-barred
# selectman-township
# roundabout-underpass
# contributions-contribution
# sq_m-sq_km
# hiring-employment
# craftsmen-artisans
# supported-support
# dour-dismal
# dollar-rand
# dine-eat
# shenanigans-theatrics
# harbor-seaport
# dioxin-contaminated
# automobile-automotive
# sells-produces
# drunk_driving-substance_abuse
# fat-chubby
# catastrophe-devastation
# burgers-tacos
# firms-suppliers
# travails-struggles
# divorced-estranged
# playlist-soundtrack
# misguided-ineffective
# limo-bus
# emails-messages
# presumably-ostensibly
# polluting-polluted
# lingerie-clothing
# financially-economically
# inconvenienced-disrupted
# badly_burned-charred
# elegant-earthy
# plumbers-plumbing
# illegals-migrants
# sold-shipped
# bachelor-doctorate
# prosecuted-imprisoned
# consensual_sex-raped
# big-biggest
# villains-characters
# professors-students
# trees-seedlings
# budget_deficits-joblessness
# likable-endearing
# jets-drones
# bumbling-ineffectual
# cuts-cut
# shortchanged-neglected
# restaurateur-eatery
# hasty-haphazard
# beverages-food
# grapes-crops
# taller-undersized
# naked-bare
# firm-company
# private_equity-buyout
# spouses-servicemembers
# entertainers-performers
# homosexual-homosexuality
# sell-distribute
# broadens-expands
# painter-poet
# secretive-reclusive
# cowboys-rodeo
# dietary-nutrition
# coal_fired-coal_mines
# vineyard-orchard
# idling-idled
# ravages-ravaged
# pickle-potato
# globalization-industrialization
# conservatives-hard_liners
# letting-forcing
# hurricane-cyclone
# conservatism-nationalism
# owners-operators
# sailboat-cargo_ship
# devious-wicked
# splendid-wondrous
# esteemed-acclaimed
# coconut-rice
# pretends-fails
# binoculars-flashlights
# populous-most_populous
# allocations-allocation
# dinners-meals
# girlfriend-stepfather
# carbon_emissions-pollution
# reinventing-transforming
# whopping-paltry
# desires-yearning
# ridiculously-downright
# smarting-reeling
# misbehavior-indiscipline
# mild_mannered-soft_spoken
# punted-fumbled
# lust-longing
# married_couples-lesbian_couples
# racetrack-mile_oval
# kidnap-abductions
# immoral-inhumane
# straightforward-simplest
# advises-directs
# smarter-better
# convicts-inmates
# gay-transgender
# putts-par_putt
# profits-quarterly
# inundated-flooded
# bad-poor
# asking-begging
# cautious-upbeat
# patriots-revolutionaries
# cocktail-concoction
# cronies-loyalists
# flute-percussion
# condo-apartment_complex
# ominously-ominous
# paintings-poems
# thank-greatly_appreciated
# considerate-sincere
# lovely-enchanting
# landowners-farmers
# fabulous-unforgettable
# crimes-massacres
# libertarian-socialist
# weakening-worsening
# multimillionaire-entrepreneur
# daughters-children
# dementia-epilepsy
# flyers-leaflets
# colonial-colonial_rule
# democrats-democratic
# nefarious-subversive
# able-unable
# marries-transforms
# strolled-trudged
# inform-disseminate
# tanked-tumbled
# plastic_surgeon-surgeons
# excesses-abuses
# preserving-revitalizing
# dark_chocolate-cinnamon
# disagreed-disputed
# homeowners-residents
# surprised-speechless
# distaste-discontent
# credit_cards-debit_cards
# taxpayers-citizens
# carbs-diets
# freedoms-democratic_reforms
# advantageous-problematic
# mugs-t_shirts
# prominent-recognizable
# cowardly-barbaric
# wanted-needed
# mistakes-shortcomings
# interest_rates-repo_rate
# bashing-pummeling
# worked-labored
# lawyer-attorney
# brunch-appetizer
# jolly-cheery
# tax_evasion-corruption
# foundations-foundation
# dessert-dish
# flashy-dazzling
# hedge_funds-counterparties
# assumes-undertakes
# uninjured-dazed
# grilling-cooking
# stem_cell-transplantation
# art_gallery-visual_arts
# evade-elude
# contributors-contributor
# happy-overjoyed
# grand_larceny-aggravated_battery
# blonde-girl
# posh-chic
# municipal-municipality
# rid-eradicate
# spooked-jolted
# post_mortem-autopsy
# lemon-mango
# disgusting-filth
# fraud-irregularities
# entities-agencies
# heavily_populated-densely_populated
# west-northwest
# credit_card-debit_card
# hedge_fund_managers-investors
# upturn-upsurge
# yard_freestyle-meter_dash
# knitting-sewing
# manager-coordinator
# enlightened-enlightenment
# conservative-evangelical
# fireplace-stove
# burdens-hardships
# disgrace-shambles
# silly-meaningless
# lake-rivers
# storm-floods
# broaden-augment
# derailing-halting
# pensions-pensioners
# insure-guarantee
# panties-clothes
# moderating-stabilizing
# nonprofits-food_pantries
# happier-brighter
# embroiled-mired
# florist-flower
# bevy-plethora
# principals-elementary_schools
# flattering-unflattering
# indicted-pleading_guilty
# mafia-criminal_gangs
# quakes-quake
# postponing-delayed
# foolish-futile
# consultants-specialists
# bearing_liabilities-stockholders_equity
# frost-rains
# liberated-liberation
# developed-develop
# consults-evaluates
# anarchists-demonstrators
# perpetuate-legitimize
# finesse-grit
# immigration-refugee
# obvious-undeniable
# tent-encampment
# painting-coloring
# composers-musical
# leaking-seeping
# lavender-herb
# semen-urine

# %% [markdown]
# ### Step 3: Analyzing socioeconomic bias in word vectors associated with professions

# %%
# profession analysis socioecomic status
sp_se = sorted([(E_se.v(w).dot(v_se), w) for w in profession_words])

sp_se[0:20], sp_se[-20:]
# Out:
# ([(-0.1363303, 'missionary'),
#   (-0.118660614, 'performer'),
#   (-0.11678807, 'lyricist'),
#   (-0.109490275, 'artiste'),
#   (-0.10128166, 'envoy'),
#   (-0.08714663, 'laborer'),
#   (-0.08581598, 'minister'),
#   (-0.08471248, 'ranger'),
#   (-0.08247355, 'technician'),
#   (-0.08150867, 'nun'),
#   (-0.07534849, 'drug_addict'),
#   (-0.07504965, 'pastor'),
#   (-0.07445507, 'major_leaguer'),
#   (-0.07175174, 'soldier'),
#   (-0.070720546, 'singer'),
#   (-0.07058622, 'prisoner'),
#   (-0.06899183, 'choreographer'),
#   (-0.068508714, 'warden'),
#   (-0.06536086, 'understudy'),
#   (-0.064544156, 'pathologist')],
#  [(0.14112504, 'restaurateur'),
#   (0.1414366, 'architect'),
#   (0.14270231, 'housekeeper'),
#   (0.14558473, 'jeweler'),
#   (0.15168333, 'baron'),
#   (0.152001, 'interior_designer'),
#   (0.15693706, 'accountant'),
#   (0.16227153, 'collector'),
#   (0.16358331, 'philanthropist'),
#   (0.16491355, 'tycoon'),
#   (0.16985941, 'lawyer'),
#   (0.17088652, 'butler'),
#   (0.18480188, 'realtor'),
#   (0.20747714, 'stockbroker'),
#   (0.20835778, 'businessman'),
#   (0.20883048, 'socialite'),
#   (0.21903986, 'investment_banker'),
#   (0.23716527, 'industrialist'),
#   (0.24934193, 'financier'),
#   (0.2820943, 'banker')])

# %% [markdown]
# ### Step 4: Debias based on socioeconomic status

# %%
# Lets load some socioecomic status related word lists to help us with debiasing
with open('./data/se_definitional_pairs.json', "r") as f:
    se_defs = json.load(f)
print("definitional", se_defs)

with open('./data/se_equalize_pairs.json', "r") as f:
    se_equalize_pairs = json.load(f)
print("equalize", se_equalize_pairs)
with open('./data/se_specific_seed.json', "r") as f:
    se_specific_words = json.load(f)
print("gender specific", len(se_specific_words), se_specific_words[:10])
# Out:
# definitional [['rich', 'poor'], ['wealthy', 'impoverished'], ['wealth', 'poverty'], ['privileged', 'disadvantaged'], ['white_collar', 'blue_collar'], ['owner', 'employee'], ['upper', 'lower'], ['extravagant', 'basic'], ['opulent', 'modest'], ['surplus', 'deficit']]
# equalize [['yacht', 'dinghy'], ['yachts', 'dinghies'], ['mansion', 'apartment'], ['mansions', 'apartments'], ['white_collar', 'blue_collar'], ['employer', 'employee'], ['employers', 'employees'], ['new_car', 'used_car'], ['lord', 'surf']]
# gender specific 16 ['yacht', 'dinghy', 'yachts', 'dinghies', 'mansion', 'apartment', 'mansions', 'apartments', 'white_collar', 'blue_collar']

# %%
debias(E_se, se_specific_words, se_defs, se_equalize_pairs)
# Out:
# 26423 words of dimension 300 : in, for, that, is, ..., Jay, Leroy, Brad, Jermaine
# {('employer', 'employee'), ('mansion', 'apartment'), ('WHITE_COLLAR', 'BLUE_COLLAR'), ('LORD', 'SURF'), ('mansions', 'apartments'), ('White_Collar', 'Blue_Collar'), ('MANSIONS', 'APARTMENTS'), ('lord', 'surf'), ('YACHTS', 'DINGHIES'), ('MANSION', 'APARTMENT'), ('new_car', 'used_car'), ('Employer', 'Employee'), ('Mansion', 'Apartment'), ('Mansions', 'Apartments'), ('Yacht', 'Dinghy'), ('NEW_CAR', 'USED_CAR'), ('Yachts', 'Dinghies'), ('EMPLOYER', 'EMPLOYEE'), ('New_Car', 'Used_Car'), ('employers', 'employees'), ('YACHT', 'DINGHY'), ('Employers', 'Employees'), ('EMPLOYERS', 'EMPLOYEES'), ('Lord', 'Surf'), ('yachts', 'dinghies'), ('yacht', 'dinghy'), ('white_collar', 'blue_collar')}
# 26423 words of dimension 300 : in, for, that, is, ..., Jay, Leroy, Brad, Jermaine

# %% [markdown]
# ### Step 5: Analyzing age bias in professions post debiasing

# %%
# profession analysis socioecomic status
sp_se_debiased = sorted([(E_se.v(w).dot(v_se), w) for w in profession_words])

sp_se_debiased[0:20], sp_se_debiased[-20:]
# Out:
# ([(-0.16797233, 'employee'),
#   (-0.13171333, 'artiste'),
#   (-0.11455773, 'lyricist'),
#   (-0.110702515, 'performer'),
#   (-0.10799282, 'envoy'),
#   (-0.10408275, 'entertainer'),
#   (-0.10313272, 'choreographer'),
#   (-0.09875187, 'vocalist'),
#   (-0.09643534, 'singer'),
#   (-0.08758396, 'protege'),
#   (-0.08690682, 'missionary'),
#   (-0.08083978, 'maestro'),
#   (-0.07951636, 'soloist'),
#   (-0.0752451, 'dancer'),
#   (-0.07424241, 'cinematographer'),
#   (-0.07296255, 'assistant_professor'),
#   (-0.072925545, 'minister'),
#   (-0.07290186, 'composer'),
#   (-0.07273125, 'warden'),
#   (-0.071610466, 'understudy')],
#  [(0.07854535, 'psychologist'),
#   (0.07855992, 'fighter_pilot'),
#   (0.07865458, 'businesswoman'),
#   (0.08034091, 'handyman'),
#   (0.08201269, 'pundit'),
#   (0.082914785, 'broker'),
#   (0.083283305, 'investment_banker'),
#   (0.083394065, 'cab_driver'),
#   (0.08365481, 'accountant'),
#   (0.08433533, 'lawyer'),
#   (0.08477233, 'fireman'),
#   (0.09080547, 'landlord'),
#   (0.092140645, 'financier'),
#   (0.09338086, 'businessman'),
#   (0.0980241, 'mathematician'),
#   (0.11127143, 'pollster'),
#   (0.11638672, 'realtor'),
#   (0.12191036, 'plumber'),
#   (0.14775515, 'banker'),
#   (0.14780602, 'stockbroker')])

# %% [markdown]
# ### Step 6: Analyzing debiased analogies

# %%
# analogies age
a_se_debiased = E_se.best_analogies_dist_thresh(v_se)

for (a,b,c) in a_se_debiased:
    print(a+"-"+b)
# Out:
# Computing neighbors
# Mean: 10.148734057449948
# Median: 7.0
# wealthy-impoverished
# employer-employee
# employees-employers
# white_collar-blue_collar
# townhouse-apartment
# townhouses-apartments
# mansions-homes
# wealthiest-poorest
# yachts-fishing_boats
# yacht-fishing_boat
# mansion-bungalow
# wealthier-poorer
# modest-meager
# earners-earner
# small-tiny
# nice-awesome
# rich-poverty_stricken
# lonely-desolate
# large-vast
# communists-communist
# phenomenal-awe_inspiring
# millionaire-mogul
# brilliant-mesmerizing
# lovely-enchanting
# suburbs-metropolis
# educated-illiterate
# clever-inventive
# fascism-totalitarian
# terrorists-guerrillas
# rational-illogical
# big-gigantic
# dumb-uneducated
# batters-mound
# compelling-captivating
# compromise-accord
# polling-polling_stations
# draconian-repressive
# elites-rulers
# revolt-uprising
# cowardly-barbaric
# sells-produces
# inequality-deprivation
# attractive-alluring
# substantial-immense
# swine_flu-outbreak
# disagreed-disputed
# hard_nosed-gritty
# radical-revolutionary
# surprised-speechless
# divorced-estranged
# pessimism-despair
# refugee-refugee_camps
# putts-par_putt
# likable-endearing
# short_sighted-ill_advised
# continental-continent
# obvious-undeniable
# liberals-hardliners
# increase-upsurge
# frantic-chaotic
# sensible-appropriate
# ridge-plains
# heterosexual-sexuality
# couples-brides
# affluent-populous
# stupid-useless
# database-repository
# good-unbelievable
# skinny-emaciated
# supports-integrates
# steak-entree
# credit_crunch-turmoil
# prospered-flourished
# buys-seizes
# lousy-abysmal
# nicely-beautifully
# falling-plunging
# reforms-democratic_reforms
# wide_range-array
# salmonella-contaminated
# discrimination-oppression
# dry-parched
# thoughtful-thought_provoking
# remarkable-wondrous
# terrorism-militancy
# superb-exquisite
# nail_biting-enthralling
# memorable-unforgettable
# gridlock-chaos
# threes-swished
# wily-mercurial
# liberalism-modernity
# extremists-tribal_regions
# fickle-unpredictable
# turbulence-instability
# defensively-offensive
# exceptions-exception
# smartest-funniest
# superior-unmatched
# weaken-destabilize
# roundabout-thoroughfare
# conclusive-inconclusive
# married_couples-newlyweds
# happy-ecstatic
# clearer_picture-glimpse
# ought-shall
# exempt-barred
# cliff-abyss
# reactionary-authoritarian
# buffeted-wracked
# florist-flower
# luxury-opulent
# advocating-denouncing
# liberal-leftist
# global_warming-deforestation
# voting-balloting
# mild_mannered-charismatic
# clarinet-percussion
# professor-associate_professor
# congestion-congested
# prominent-renowned
# dreamy-lush
# plausible-improbable
# advocated-denounced
# applauds-celebrates
# disliked-adored
# dour-drab
# burglary-drug_paraphernalia
# crimes-massacres
# mistakes-misstep
# burglarized-ransacked
# fortunate-blessed
# voter_fraud-vote_rigging
# businesses-communities
# refiners-refiner
# disorderly-unruly
# prosecuted-imprisoned
# urging-vowing
# condom-condoms
# esteem-reverence
# capitalists-peasants
# young-youth
# corporations-enterprises
# cute-adorable
# eyeglasses-spectacles
# anticipating-anticipation
# mellow-earthy
# regional-region
# helpful-invaluable
# middle_aged-bearded
# empathy-sincerity
# mentally-spiritually
# tricky-perilous
# colds-diarrhea
# exempted-banned
# cheerful-joyful
# maths-pupils
# uptight-overbearing
# contacted-visited
# layups-inbounds_pass
# loudspeaker-loudspeakers
# inclined-compelled
# harbor-seaport
# breakfast-banquet
# heartened-awed
# predictability-unpredictability
# post_mortem-autopsy
# defrauded-misappropriated
# silly-tacky
# fairly-incredibly
# stimulating-invigorating
# smitten-enchanted
# sheltered-refuge
# civil_liberties-democracy
# renewables-hydropower
# cottages-shacks
# appease-pacify
# led-culminated
# venture_capitalist-co_founder
# catastrophe-devastation
# criminality-lawlessness
# consumption-consumes
# funny-hilarious
# recessions-crises
# mortgage-mortgage_lender
# broadens-expands
# generally-routinely
# pretty_darn-downright
# wishful_thinking-exaggeration
# conundrum-enigma
# cuts-slash
# pessimistic-bleak
# married-bride
# conservatism-nationalism
# deduction-deducted
# inform-disseminate
# beach-island
# thinks-feels
# accessible-inaccessible
# sleazy-seedy
# tend-oftentimes
# terrorist-militant
# dishonest-corrupt
# continual-unending
# dropped-plunged
# interest_rates-central_bank
# lipstick-glitter
# disproportionately-disproportionate
# hills-mountainous
# sexist-vulgar
# jumped-surged
# clobbered-pummeled
# groundswell-outpouring
# supportive-appreciative
# homeless-destitute
# communism-communist_regime
# blond-brown_eyes
# smartly-expertly
# families-loved_ones
# shoreline-peninsula
# fats-nutrients
# penalize-impose_sanctions
# villa-palace
# mirroring-reminiscent
# philosophical-existential
# defer-suspend
# shortfall-shortages
# applies-uses
# uninjured-dazed
# databases-repositories
# cannabis-narcotic
# seeing-witnessing
# basically-practically
# liked-relished
# communicating-interact
# dogged-marred
# respected-revered
# asking-begging
# discriminatory-unjust
# countywide-county
# whole-entire
# wife-aunt
# accountants-auditors
# decent-splendid
# slavery-colonial_rule
# silliness-theatrics
# surprisingly-undeniably
# likeable-charisma
# heavily_populated-sparsely_populated
# terrific-incredible
# sandwiches-delicacies
# sharpening-polishing
# changes-transformations
# sq_m-sq_km
# handful-dozens
# renewable_energy-hydroelectric
# satisfying-exhilarating
# macho-bravado
# understand-comprehend
# uber-insanely
# presume-deem
# moderator_review-flag_icon_below
# socialists-revolutionaries
# swamped-overflowed
# geeks-aficionados
# broadening-bolstering
# financially-economically
# gung_ho-apprehensive
# fatal-deadly
# tackles-rusher
# bunt-batter_box
# renovating-dilapidated
# smoke_inhalation-pronounced_dead
# negotiators-envoys
# distraught-devastated
# conservatives-hard_liners
# indicates-indication
# private_equity-leveraged_buyout
# gay-queer
# important-integral_part
# brick_wall-walls
# ethnicity-ethnic
# endorsed-endorsement
# staffing-understaffed
# admire-marvel
# skill-talents
# lowers-soars
# multimillionaire-tycoon
# maverick-firebrand
# piano-musical
# minimalist-evocative
# pretend-forget
# transitioned-transformed
# downsize-reconfigure
# playlist-soundtrack
# man-boy
# despicable-deplorable
# basic-rudimentary
# tough-toughest
# strenuous-exhausting
# philosopher-poet
# thanking-gratitude
# self_employed-freelance
# cautious-jittery
# dayers-sub_continent
# prostate_cancer-radiation_therapy
# chord-melodies
# mammals-fauna
# inventories-stockpiles
# tax-levies
# hurricane-cyclone
# classy-elegance
# reasonably-exceedingly
# drilling-exploration
# museums-treasures
# stubborn-unyielding
# reward-bounty
# suggests-finds
# straightforward-intuitive
# carbon_emissions-pollution
# painted-adorned
# marinas-waterways
# profound-immeasurable
# worked-toiled
# aided-augmented
# gal-diva
# salary-signing_bonus
# dreadful-glorious
# heartless-wicked
# resign-ouster
# cadre-cadres
# taxpayers-taxpayer_dollars
# lethargic-lifeless
# stuck-mired
# crowded-teeming
# statewide-state
# chords-rhythms
# limit-curtail
# gaps-void
# centrist-reformist
# talking-reminiscing
# myth-mythology
# advising-instructed
# redefine-transform
# dredging-reclamation
# hippies-psychedelic
# toes-paws
# bruises-scars
# thrillers-melodrama
# meats-spices
# white-purple
# conforming-conformity
# demonstrate-showcase
# sanctity-sacred
# protecting-safeguarding
# complicated-fraught
# expire-expired
# racism-colonialism
# suggested-hinted
# screwing-ruining
# hanging-dangling
# wins-triumph
# law-constitution
# bacon-fried
# boils_down-entails
# misdemeanors-child_endangerment
# firemen-policemen
# boats-warships
# key-integral
# caved-crumbled
# furious-seething
# crowding-overcrowded
# ag-agricultural
# insurance-insurer
# remarkably-delightfully
# rowdy-raucous
# blended-infused
# intrusions-incursions
# divides-straddles
# clean_sheets-goalscoring
# introduces-transforms
# wielding-wields
# adventurer-adventure
# warm-warmth
# sweet-fragrant
# forested-jungles
# principles-teachings
# geniuses-genius
# provincial-province
# caters-operates
# frustrated-overwhelmed
# sized-oversized
# crude_inventories-crude
# hammering-pounding
# puzzled-pained
# rebuild-ravaged
# badly_burned-charred
# assumes-undertakes
# masculine-sensual
# priced-overpriced
# registered-logged
# sailor-warship
# simple-simplest
# anxiety-hopelessness
# charges-allegation
# moral-spiritual
# book-tome
# winds-torrential_rains
# easy-effortless
# globalization-industrialization
# subtlety-artistry
# backwards-backward
# defrauding-embezzled
# remember-relive
# flip_flops-sandals
# creepy-eerie
# disdain-defiance
# simpler-cumbersome
# suggesting-hinting
# unscathed-untouched
# muffins-delicious
# fliers-pamphlets
# great-amazing
# sputtering-moribund
# helps-utilizes
# sued-alleging
# earthly-mystical
# reasonable-adequate
# wealth-riches
# pushing-bringing
# cheering-jubilation
# keynote_speaker-emcee
# presumably-ostensibly
# criminals-criminal_gangs
# torture-brutality
# pushes-pours
# wreckage-ruins
# treaty-disarmament
# eliminate-eradicate
# leftists-dictatorships
# bales-tons
# nuisance-eyesore
# cocky-swagger
# respects-homage
# identifies-uncovers
# flattering-unflattering
# unforced_errors-forehand
# evenly_split-divided
# income-revenues
# retorted-exclaimed
# boss-supremo
# harder-impossible
# perfectly-wonderfully
# overspending-mismanagement
# honey-herb
# warehousing-warehouses
# bounces-spins
# supported-spearheaded
# affordability-accessibility
# concerted_effort-attempt
# melanoma-lymph_nodes
# dwellers-inhabitants
# buddies-comrades
# despondent-demoralized
# boundaries-frontiers
# roughly-nearly
# talked-raved
# smattering-sprinkled
# misled-mismanaged
# gun-weapons
# unfairly-unjustly
# credibility-legitimacy
# points-leading_scorer
# implicit-tacit
# socialism-dictatorship
# ingrained-permeated
# slight-slightest
# guys-stuff
# bakers-artisans
# emissions-soot
# gaggle-throngs
# budding-blossoming
# attackers-militants
# huge-enormous
# conservative-evangelical
# rib_injury-ankle_injury
# stellar-dazzling
# burglaries-armed_robbery
# disagreements-tensions
# felonies-probation_violation
# doomed-destined
# wary-uneasy
# homeowners-residents
# insolvency-bankruptcy_filing
# human_beings-peoples
# ski-resorts
# colleague-comrade
# permissible-forbidden
# speculators-traders
# fewer-more
